# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torchvision.utils
import torch.autograd as autograd

cuda = True if torch.cuda.is_available() else False
Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor

# %% [markdown]
# **Hyperparameters**

# %%
class Para():
    def __init__(self):
        self.latent_dim = 10 # latent space dimention
        self.img_shape = (1, 28, 28) # image shape (1x28x28 for MNIST)
        self.generator_path = 'G_l10_woBN.pth' # pre-trained generator path
        self.discriminator_path = 'D_l10_woBN.pth' # pre-trained discriminator path
        self.batch_size = 25 # batch size for visualization
        
opt = Para()

# %% [markdown]
# **Network architectures**

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        def block(in_feat, out_feat, normalize=False):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(opt.latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(opt.img_shape))),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.shape[0], *opt.img_shape)
        return img

    
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(opt.img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
        )

    def forward(self, img):
        img_flat = img.view(img.shape[0], -1)
        validity = self.model(img_flat)
        return validity

    
# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

if cuda:
    generator.cuda()
    discriminator.cuda()

# %% [markdown]
# **Load networks**

# %%
generator.load_state_dict(torch.load(opt.generator_path))
discriminator.load_state_dict(torch.load(opt.discriminator_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-da9e140d3736> in <module>
# ----> 1 generator.load_state_dict(torch.load(opt.generator_path))
#       2 discriminator.load_state_dict(torch.load(opt.discriminator_path))
#
# C:\ProgramData\Miniconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'G_l10_woBN.pth'

# %% [markdown]
# **Generator and discriminator visualization**

# %%
def vis(y, nrow, title='figure'):
    imgs = torchvision.utils.make_grid(y, nrow=nrow, padding=0, normalize=True)

    if cuda:
        plt.imshow(imgs.permute(1, 2, 0).cpu())
    else:
        plt.imshow(imgs.permute(1, 2, 0))
    plt.title(title)
    plt.show()

# %%
z = Variable(Tensor(np.random.normal(0, 1, (opt.batch_size, opt.latent_dim)))) # latend variables

with torch.no_grad():
    generated_imgs = generator(z) # generate images
    validity = discriminator(generated_imgs) # discriminator validaty

vis(generated_imgs, nrow=int(np.sqrt(opt.batch_size)))

# %% [markdown]
# **GD**

# %% [markdown]
# $$\min_uJ(u)=\frac{1}{2}\|G(u)-y\|_2^2$$
# $$u_{k+1}=u_k-\alpha_kDJ(u)$$

# %%
u_gt = Variable(Tensor(np.random.normal(0, 1, (5, opt.latent_dim)))) # ground truth u
with torch.no_grad():
    y = generator(u_gt) # generated y from u_gt

# %%
# Visualization of u_gt and y
print(u_gt.shape)
print(y.shape)
vis(y, nrow=5)
# Out:
# torch.Size([5, 10])
# torch.Size([5, 1, 28, 28])

# %%
# GD
loss = nn.MSELoss()
u_hat = Variable(Tensor(np.random.normal(0, 0.2, (5, opt.latent_dim))), requires_grad=True)
u_0 = u_hat
alpha = 5e-3
epoch = 40000

l = []
for i in range(epoch):
    l.append(loss(generator(u_hat), y).item())
    if i % 500 == 0:
        print('['+str(i)+'/'+str(epoch)+']', loss(generator(u_hat), y))
    grad = autograd.grad(outputs=loss(generator(u_hat), y), inputs=u_hat)[0]
    u_hat = u_hat - alpha * grad

plt.plot(l)
plt.title('GD loss curve')
plt.show()
# Out:
# [0/40000] tensor(2.0672, device='cuda:0', grad_fn=<MseLossBackward>)
# [500/40000] tensor(0.4768, device='cuda:0', grad_fn=<MseLossBackward>)
# [1000/40000] tensor(0.4165, device='cuda:0', grad_fn=<MseLossBackward>)
# [1500/40000] tensor(0.3992, device='cuda:0', grad_fn=<MseLossBackward>)
# [2000/40000] tensor(0.3849, device='cuda:0', grad_fn=<MseLossBackward>)
# [2500/40000] tensor(0.3618, device='cuda:0', grad_fn=<MseLossBackward>)
# [3000/40000] tensor(0.3371, device='cuda:0', grad_fn=<MseLossBackward>)
# [3500/40000] tensor(0.3224, device='cuda:0', grad_fn=<MseLossBackward>)
# [4000/40000] tensor(0.3155, device='cuda:0', grad_fn=<MseLossBackward>)
# [4500/40000] tensor(0.3097, device='cuda:0', grad_fn=<MseLossBackward>)
# [5000/40000] tensor(0.3046, device='cuda:0', grad_fn=<MseLossBackward>)
# [5500/40000] tensor(0.3008, device='cuda:0', grad_fn=<MseLossBackward>)
# [6000/40000] tensor(0.2972, device='cuda:0', grad_fn=<MseLossBackward>)
# [6500/40000] tensor(0.2941, device='cuda:0', grad_fn=<MseLossBackward>)
# [7000/40000] tensor(0.2900, device='cuda:0', grad_fn=<MseLossBackward>)
# [7500/40000] tensor(0.2861, device='cuda:0', grad_fn=<MseLossBackward>)
# [8000/40000] tensor(0.2820, device='cuda:0', grad_fn=<MseLossBackward>)
# [8500/40000] tensor(0.2776, device='cuda:0', grad_fn=<MseLossBackward>)
# [9000/40000] tensor(0.2726, device='cuda:0', grad_fn=<MseLossBackward>)
# [9500/40000] tensor(0.2649, device='cuda:0', grad_fn=<MseLossBackward>)
# [10000/40000] tensor(0.2589, device='cuda:0', grad_fn=<MseLossBackward>)
# [10500/40000] tensor(0.2547, device='cuda:0', grad_fn=<MseLossBackward>)
# [11000/40000] tensor(0.2492, device='cuda:0', grad_fn=<MseLossBackward>)
# [11500/40000] tensor(0.2443, device='cuda:0', grad_fn=<MseLossBackward>)
# [12000/40000] tensor(0.2398, device='cuda:0', grad_fn=<MseLossBackward>)
# [12500/40000] tensor(0.2350, device='cuda:0', grad_fn=<MseLossBackward>)
# [13000/40000] tensor(0.2305, device='cuda:0', grad_fn=<MseLossBackward>)
# [13500/40000] tensor(0.2260, device='cuda:0', grad_fn=<MseLossBackward>)
# [33000/40000] tensor(0.1715, device='cuda:0', grad_fn=<MseLossBackward>)
# [33500/40000] tensor(0.1712, device='cuda:0', grad_fn=<MseLossBackward>)
# [34000/40000] tensor(0.1709, device='cuda:0', grad_fn=<MseLossBackward>)
# [34500/40000] tensor(0.1707, device='cuda:0', grad_fn=<MseLossBackward>)
# [35000/40000] tensor(0.1704, device='cuda:0', grad_fn=<MseLossBackward>)
# [35500/40000] tensor(0.1702, device='cuda:0', grad_fn=<MseLossBackward>)
# [36000/40000] tensor(0.1700, device='cuda:0', grad_fn=<MseLossBackward>)
# [36500/40000] tensor(0.1697, device='cuda:0', grad_fn=<MseLossBackward>)
# [37000/40000] tensor(0.1695, device='cuda:0', grad_fn=<MseLossBackward>)
# [37500/40000] tensor(0.1693, device='cuda:0', grad_fn=<MseLossBackward>)
# [38000/40000] tensor(0.1691, device='cuda:0', grad_fn=<MseLossBackward>)
# [38500/40000] tensor(0.1689, device='cuda:0', grad_fn=<MseLossBackward>)
# [39000/40000] tensor(0.1687, device='cuda:0', grad_fn=<MseLossBackward>)
# [39500/40000] tensor(0.1685, device='cuda:0', grad_fn=<MseLossBackward>)

# %%
# Visualization of y_hat and y
vis(y, nrow=5, title='y')

with torch.no_grad():
    y_hat = generator(u_hat)
    y_hat_0 = generator(u_0)
vis(y_hat_0, nrow=5, title='y_hat (before GD)')
vis(y_hat, nrow=5, title='y_hat (after GD)')

# %% [markdown]
# **Noise model $y=G(u)+\eta$**
#
# We have prior $u\sim\mathcal(m,I)$ and noise model $\eta\sim\mathcal(0,a\cdot I)$. Using Andrew's notations we will have:
# $$\min_uJ(u)=\frac{1}{2}\|G(u)-y\|_{a\cdot I}^2+\frac{1}{2}\|u-m\|_{I}^2=\frac{1}{2a}\|G(u)-y\|_2^2+\frac{1}{2}\|u-m\|_2^2$$
# $$u_{k+1}=u_k-\alpha_kDJ(u)$$

# %%
a = 0.2
u_gt = Variable(Tensor(np.random.normal(0, 1, (5, opt.latent_dim)))) # ground truth u
eta = Variable(Tensor(np.random.normal(0, a, (5, *opt.img_shape)))) # noise
m = Tensor(np.zeros((5, opt.latent_dim)))
with torch.no_grad():
    y = generator(u_gt) + eta # generated y from u_gt
    y_gt = generator(u_gt)

# %%
# Visualization of u_gt and y
print(u_gt.shape)
print(y.shape)
vis(y, nrow=5, title='y')
vis(y_gt, nrow=5, title='y_gt (w/o noise)')
# Out:
# torch.Size([5, 10])
# torch.Size([5, 1, 28, 28])

# %%
# GD with noise
loss = nn.MSELoss()
u_hat = Variable(Tensor(np.random.normal(0, 0.2, (5, opt.latent_dim))), requires_grad=True)
u_0 = u_hat
alpha = 5e-3
epoch = 40000

l = []
for i in range(epoch):
    l.append((loss(generator(u_hat), y) + a*loss(u_hat, m)).item())
    if i % 500 == 0:
        print('['+str(i)+'/'+str(epoch)+']', loss(generator(u_hat), y) + a*loss(u_hat, m))
    grad = autograd.grad(outputs=loss(generator(u_hat), y) + a*loss(u_hat, m), inputs=u_hat)[0]
    u_hat = u_hat - alpha * grad

plt.plot(l)
plt.title('GD loss curve')
# [38000/40000] tensor(0.0926, device='cuda:0', grad_fn=<AddBackward0>)
# [38500/40000] tensor(0.0926, device='cuda:0', grad_fn=<AddBackward0>)
# [39000/40000] tensor(0.0926, device='cuda:0', grad_fn=<AddBackward0>)
# [39500/40000] tensor(0.0925, device='cuda:0', grad_fn=<AddBackward0>)

# %%
# Visualization of y_hat and y
vis(y, nrow=5, title='y')
vis(y_gt, nrow=5, title='y_gt (w/o noise)')
with torch.no_grad():
    y_hat = generator(u_hat)
    y_hat_0 = generator(u_0)
vis(y_hat_0, nrow=5, title='y_hat (before GD)')
vis(y_hat, nrow=5, title='y_hat (after GD)')

# %% [markdown]
# **Noise model $y=G(u)+\eta$**
#
# Now we change the noise as Poisson noise
#
# We have prior $u\sim\mathcal(m,I)$ and noise model $P(\eta = k)=\lambda^k e^{-\lambda}/k!$. Here $\lambda$ is the mean pixel value of the pic. Using Andrew's notations we will have:
# $$\min_uJ(u)=\frac{1}{2}\|G(u)-y\|_{a\cdot I}^2+\frac{1}{2}\|u-m\|_{I}^2=\frac{1}{2a}\|G(u)-y\|_2^2+\frac{1}{2}\|u-m\|_2^2$$
# $$u_{k+1}=u_k-\alpha_kDJ(u)$$

# %%
u_gt = Variable(Tensor(np.random.normal(0, 1, (5, opt.latent_dim)))) # ground truth u

m = Tensor(np.zeros((5, opt.latent_dim)))
with torch.no_grad():
    y_gt = generator(u_gt)
y_gt_cpu = y_gt.cpu().numpy()
mean_y_gt = np.mean(y_gt_cpu)+1
eta = Variable(Tensor(np.random.poisson(mean_y_gt,size=(5, *opt.img_shape)))) # noise
with torch.no_grad():
    y = generator(u_gt) + eta # generated y from u_gt

# %%
# Visualization of u_gt and y
print(u_gt.shape)
print(y.shape)
vis(y, nrow=5, title='y')
vis(y_gt, nrow=5, title='y_gt (w/o noise)')
# Out:
# torch.Size([5, 10])
# torch.Size([5, 1, 28, 28])

# %%
# GD with Poisson Noise
loss = nn.MSELoss()
u_hat = Variable(Tensor(np.random.normal(0, 0.2, (5, opt.latent_dim))), requires_grad=True)
u_0 = u_hat
alpha = 5e-3
epoch = 40000
a = 0.2
l = []
for i in range(epoch):
    l.append((loss(generator(u_hat), y) + a*loss(u_hat, m)).item())
    if i % 500 == 0:
        print('['+str(i)+'/'+str(epoch)+']', loss(generator(u_hat), y) + a*loss(u_hat, m))
    grad = autograd.grad(outputs=loss(generator(u_hat), y) + a*loss(u_hat, m), inputs=u_hat)[0]
    u_hat = u_hat - alpha * grad

plt.plot(l)
plt.title('GD loss curve')
plt.show()
# Out:
# [0/40000] tensor(1.9115, device='cuda:0', grad_fn=<AddBackward0>)
# [500/40000] tensor(0.7693, device='cuda:0', grad_fn=<AddBackward0>)
# [1000/40000] tensor(0.7214, device='cuda:0', grad_fn=<AddBackward0>)
# [1500/40000] tensor(0.6878, device='cuda:0', grad_fn=<AddBackward0>)
# [2000/40000] tensor(0.6650, device='cuda:0', grad_fn=<AddBackward0>)
# [2500/40000] tensor(0.6352, device='cuda:0', grad_fn=<AddBackward0>)
# [3000/40000] tensor(0.6119, device='cuda:0', grad_fn=<AddBackward0>)
